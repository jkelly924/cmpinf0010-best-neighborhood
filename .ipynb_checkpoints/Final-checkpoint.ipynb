# %% [markdown]
# # Introduction
# ---

# %% [markdown]
# ## Team Name: ***The Answer to Life, The Universe, and Everything***
#
# We came up with our submetrics by looking through the list of available datasets and finding compelling ones. From there, we figured out what information from each dataset could combine to come to a good result.

# %% [markdown]
# # The Metric
# ---

# %% [markdown]
# ## Quality of Life
#
# We are measuring this using three submetrics: **Fire Rates**, **Crime Rates**, and **Total Area**. The data sets used are:
# - [Fire Incidents in City of Pittsburgh](https://data.wprdc.org/dataset/fire-incidents-in-city-of-pittsburgh) (For Fire Rates)
# - [Neighborhoods with SNAP Data](https://data.wprdc.org/dataset/neighborhoods-with-snap-data) (For Crime Rates)
# - [Neighborhoods](https://data.wprdc.org/dataset/neighborhoods2) (For Total Area)

# %% [markdown]
# # The Best Neighborhood
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

# Print all columns and rows
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Fire Rates

# %%
# Load the CSV file
# In order for the below code to run the Fire_Incidents.CSV needs to be in the same folder as the .ipynb
houseFires = pd.read_csv("Datasets\Fire_Incidents.csv")

# Count occurrences of each neighborhood
# sorting values by ascending maintains the value so it displays from least to greatest
neighborhood_counts = (
    houseFires["neighborhood"].value_counts().sort_values(ascending=True)
)

# Display the counts for each neighborhood
print(neighborhood_counts)
# Out:
# neighborhood
# Regent Square                  9
# East Carnegie                 11
# Ridgemont                     12
# Oakwood                       13
# Arlington Heights             13
# St. Clair                     14
# Swisshelm Park                17
# Chartiers City                18
# Mt. Oliver                    18
# Glen Hazel                    20
# Summer Hill                   21
# Bon Air                       22
# New Homestead                 22
# Esplen                        23
# West End                      23
# Hays                          24
# Windgap                       24
# Fairywood                     26
# South Shore                   26
# Spring Garden                 26
# Westwood                      28
# Friendship                    33
# Morningside                   35
# Polish Hill                   39
# Duquesne Heights              41
# Allegheny West                43
# California-Kirkbride          43
# Chateau                       43
# Bedford Dwellings             47
# Upper Hill                    50
# Fineview                      50
# Point Breeze North            51
# Arlington                     52
# Upper Lawrenceville           56
# Banksville                    60
# Overbrook                     61
# Stanton Heights               62
# Lower Lawrenceville           63
# Allegheny Center              63
# Homewood West                 63
# West Oakland                  64
# Northview Heights             67
# Lincoln Place                 69
# Elliott                       72
# Point Breeze                  72
# Strip District                75
# North Shore                   77
# Highland Park                 79
# Central Lawrenceville         79
# Manchester                    82
# Crafton Heights               85
# Troy Hill                     85
# Terrace Village               87
# Central Oakland               98
# South Oakland                101
# Middle Hill                  106
# South Side Slopes            107
# Perry North                  113
# Crawford-Roberts             114
# Spring Hill-City View        115
# Garfield                     115
# Greenfield                   124
# Larimer                      127
# Allentown                    130
# North Oakland                133
# Central Northside            134
# Beltzhoover                  136
# Squirrel Hill North          136
# East Allegheny               141
# Bluff                        149
# Marshall-Shadeland           150
# Beechview                    155
# Brighton Heights             158
# East Hills                   160
# Perry South                  167
# Sheraden                     178
# Bloomfield                   182
# Homewood North               189
# Shadyside                    193
# Knoxville                    195
# Lincoln-Lemington-Belmar     200
# Homewood South               202
# Brookline                    203
# East Liberty                 220
# Mount Washington             231
# Hazelwood                    257
# Squirrel Hill South          268
# South Side Flats             289
# Central Business District    290
# Carrick                      307
# Name: count, dtype: int64
# <>:3: SyntaxWarning: invalid escape sequence '\F'
# <>:3: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\jaybu\AppData\Local\Temp\ipykernel_25064\1986200091.py:3: SyntaxWarning: invalid escape sequence '\F'
#   houseFires = pd.read_csv("Datasets\Fire_Incidents.csv")

# %%
# summary statistics on house fire incidents to find out the neighborhoods with the lowest house fire potential
print(neighborhood_counts.describe().round(2))
# Out:
# count     90.00
# mean      95.90
# std       74.15
# min        9.00
# 25%       36.00
# 50%       73.50
# 75%      136.00
# max      307.00
# Name: count, dtype: float64

# %% [markdown]
# ### Fire Safety Rankings in Neighborhoods
#
# - **The average neighborhood**
#   - Has about **95 fires**.
#   - We would assign it a safety rating of **5**.
#
# - **The highest fire count in a neighborhood**
#   - Has **307 fires**.
#   - This neighborhood would be ranked as the **unsafest** with a safety rating of **10**.
#
# - **The lowest fire count in a neighborhood**
#   - Has **9 fires**.
#   - This neighborhood would be ranked as the **safest** with a safety rating of **1**.

# %%
# Let us find the safest neighborhoods and the nsmallest command pulls back the 5 safestest neighborhood
safestNeighborhoods = neighborhood_counts.nsmallest(5)

# %%
safestNeighborhoods.plot.bar(
    x="neighborhood",
    title="Safest Neighborhoods in Pitt",
    xlabel="Neighborhoods",
    ylabel="Fire Incidents",
    rot=45,
)
plt.show()

# %%
# Les Find the unsafest neighborhoods and the nlargest command pulls back the 5 unsafestest neighborhood
unsafestNeighborhoods = neighborhood_counts.nlargest(5)

# %%
unsafestNeighborhoods.plot.bar(
    x="neighborhood",
    title="Unsafest Neighborhoods in Pitt",
    xlabel="Neighborhoods",
    ylabel="Fire Incidents",
    color="red",
    rot=45,
)
plt.show()

# %% [markdown]
# ### Summary
#
# In analyzing fire incident data, the findings reveal significant differences in safety levels across neighborhoods:
#
# - **Carrick** recorded the highest number of fire incidents, with a total of **307 incidents**. On a scale of **1 to 10** (safest to least safe), this places Carrick at a **10**.
# - **Regent Square**, on the other hand, had the lowest number of fire incidents, with only **9 incidents**. This earns it a **1** on the same safety scale.
#
# ### Conclusion
# Based on fire incident data, **Regent Square** emerges as the safest neighborhood, demonstrating the lowest risk of fire-related incidents.

# %% [markdown]
# ## Crime Rates

# %% [markdown]
# ### Gathering Data:

# %%
# Getting the data from the CSV file
snap_data = pd.read_csv(r'Datasets\Neighborhoods_with_SNAP_Data.csv')

# Picking out the information that I want
crimes = pd.DataFrame(snap_data.loc[:, 'SNAP_All_csv_Neighborhood']).join(snap_data.loc[:, 'SNAP_All_csv__Murder__2010_':'SNAP_All_csv__Drug_Violations__'])

# A series that will hold the weighted tally
weighted_crime_tally = pd.Series()

# Iterating through each neighborhood to tally them up.
for _, row in crimes.iterrows():
    crime_tally = 0
    
    # Murders and Rapes, 10 pts ea.
    crime_tally += row['SNAP_All_csv__Murder__2010_'] * 10
    crime_tally += row['SNAP_All_csv__Rape__2010_'] * 10

    # Robbery and Agr Assault, 5 pts ea.
    crime_tally += row['SNAP_All_csv__Robbery__2010_'] * 5
    crime_tally += row['F_Agr__Assault__2010_'] * 5

    # Burglary and Auto Theft, 3 pts ea.
    crime_tally += row['SNAP_All_csv__Burglary__2010_'] * 3
    crime_tally += row['SNAP_All_csv__Auto_Theft__2010_'] * 3

    # Drug Violations, 1 pts ea.
    crime_tally += row['SNAP_All_csv__Drug_Violations__'] * 1

    weighted_crime_tally[row['SNAP_All_csv_Neighborhood']] = crime_tally

weighted_crime_tally.sort_values(ascending=False, inplace=True)
weighted_crime_tally
# Out:
# South Side Flats             1078
# East Liberty                  981
# Carrick                       971
# Central Business District     774
# Mount Washington              758
# Knoxville                     745
# Homewood South                717
# Bloomfield                    715
# Perry South                   637
# Sheraden                      615
# Homewood North                594
# East Allegheny                582
# Terrace Village               557
# Marshall-Shadeland            549
# Brighton Heights              548
# Shadyside                     533
# Allentown                     453
# Garfield                      449
# Squirrel Hill South           440
# South Side Slopes             436
# Brookline                     436
# Central Oakland               412
# Larimer                       408
# Hazelwood                     405
# Beechview                     381
# Central Lawrenceville         377
# Middle Hill                   358
# Troy Hill                     356
# Crawford-Roberts              343
# Lincoln-Lemington-Belmar      334
# Spring Hill-City View         325
# Central Northside             316
# Highland Park                 300
# Fineview                      285
# Perry North                   282
# Greenfield                    282
# Strip District                282
# East Hills                    271
# North Oakland                 271
# Elliott                       264
# Lower Lawrenceville           251
# Upper Lawrenceville           242
# Bluff                         236
# Beltzhoover                   236
# South Oakland                 216
# Manchester                    212
# Crafton Heights               209
# Squirrel Hill North           197
# Northview Heights             195
# Overbrook                     184
# West Oakland                  184
# Upper Hill                    162
# Allegheny Center              160
# Point Breeze                  157
# California-Kirkbride          156
# Arlington                     150
# Stanton Heights               148
# Homewood West                 144
# Morningside                   140
# Friendship                    135
# Bedford Dwellings             130
# Point Breeze North            123
# Westwood                      107
# Allegheny West                102
# Duquesne Heights              100
# Esplen                         99
# West End                       95
# Polish Hill                    93
# Spring Garden                  93
# Windgap                        85
# Banksville                     84
# North Shore                    79
# Arlington Heights              76
# Bon Air                        60
# Lincoln Place                  59
# South Shore                    49
# Mt. Oliver                     44
# Glen Hazel                     44
# Regent Square                  42
# Chartiers City                 35
# Hays                           33
# St. Clair                      28
# Oakwood                        26
# Chateau                        25
# East Carnegie                  20
# Swisshelm Park                 18
# Summer Hill                    18
# Ridgemont                      16
# New Homestead                  10
# Fairywood                       3
# dtype: int64

# %% [markdown]
# ### Plotting Data:

# %%
# Lowest Crime
plt.figure(figsize=(10,5))

plt.bar(weighted_crime_tally.index[-1:-11:-1], weighted_crime_tally.values[-1:-11:-1], color='darkgreen')
plt.title("Top 10 Lowest Crime Neighborhoods", fontweight='bold', fontsize=24)
#plt.xlabel("Neighborhood", fontweight='bold')
plt.ylabel("Weighted Crimes", fontweight='bold')
plt.figsize = (10,100)

plt.xticks(rotation=60, rotation_mode='default')

plt.show()

print('\n\n')

# Highest Crime
plt.figure(figsize=(10,5))

plt.bar(weighted_crime_tally.index[:11], weighted_crime_tally.values[:11], color='darkred')
plt.title("Top 10 Highest Crime Neighborhoods", fontweight='bold', fontsize=24)
#plt.xlabel("Neighborhood", fontweight='bold')
plt.ylabel("Weighted Crimes", fontweight='bold')
plt.figsize = (10,100)

plt.xticks(rotation=60, rotation_mode='default')

plt.show()

# %% [markdown]
# ### Normalizing Data

# %%
# This gets a floating-point number for each neighborhood that represents the percentage of crime as related to the mean.
# So, a neighborhood with above average crime will be >1, and below average crime will be <1.
normalized_crime_data = weighted_crime_tally.div(weighted_crime_tally.mean())

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Based on crime data alone, the best neighborhood to live in is **Fairywood**, because it has the lowest crime score. Importantly, this score is based on a weight given to each kind of crime, so it is possible that another neighborhood had fewer crimes, but they were more heinous, and therefore resulted in a higher score.

# %% [markdown]
# ## Total Area

# %%
df = pd.read_csv('Neighborhoods.csv')

#  iloc to select specific columns 
filtered_df = df.iloc[:, [ 21, 23]]  
# Rename columns 
filtered_df.columns = ['hood', 'acres']
print(filtered_df)
# Out:
#                          hood        acres
# 0          Point Breeze North   193.229239
# 1         Squirrel Hill North   782.981547
# 2                    Garfield   292.726125
# 3           Bedford Dwellings   112.431551
# 4                   Knoxville   191.759777
# 5              Homewood South   247.774812
# 6                 Middle Hill   195.289986
# 7                     Oakwood   161.524977
# 8               North Oakland   318.081283
# 9            Duquesne Heights   396.515579
# 10                 Glen Hazel   292.776368
# 11               East Liberty   372.082543
# 12                   Westwood   441.883800
# 13                Morningside   239.749013
# 14              Lincoln Place   628.180805
# 15                Perry North   774.344308
# 16          Northview Heights   200.830166
# 17             Homewood North   276.834687
# 18          Arlington Heights    81.429572
# 19        Lower Lawrenceville   275.164249
# 20                    Larimer   284.917706
# 21   Lincoln-Lemington-Belmar  1163.584745
# 22                      Bluff   208.167190
# 23                  Fairywood   620.538140
# 24                  Brookline  1336.915048
# 25                       Hays  1116.862606
# 26                Beltzhoover   265.855831
# 27                 Greenfield   495.638765
# 28              East Carnegie   277.411237
# 29                North Shore   190.094754
# 30                  Allentown   190.078891
# 31                    Bon Air   201.491480
# 32             Allegheny West    92.668353
# 33            Crafton Heights   480.842673
# 34                 Manchester   178.591078
# 35         Marshall-Shadeland   802.606472
# 36              Highland Park   748.710457
# 37              New Homestead   505.581912
# 38          Central Northside   166.193982
# 39                Polish Hill   163.945111
# 40                  Overbrook   535.358235
# 41                 Friendship    67.962504
# 42              Homewood West   124.930088
# 43  Central Business District   413.204465
# 44             East Allegheny   150.345954
# 45           Allegheny Center   133.719566
# 46            Central Oakland   179.229776
# 47           Brighton Heights   714.894305
# 48          South Side Slopes   462.758482
# 49                  Arlington   307.184311
# 50             Chartiers City    85.769801
# 51                    Carrick  1068.499135
# 52                 Bloomfield   449.235596
# 53                 Banksville   625.676432
# 54           Mount Washington   724.819696
# 55                 East Hills   345.956670
# 56      Central Lawrenceville   614.471812
# 57                   West End   124.522117
# 58                     Esplen   147.915255
# 59               Point Breeze   642.171042
# 60                  Hazelwood  1027.355327
# 61           Crawford-Roberts   160.858767
# 62              South Oakland   309.733370
# 63                 Upper Hill   200.440882
# 64                  Ridgemont   228.895165
# 65                  Troy Hill   294.985078
# 66                South Shore   147.675880
# 67                 Mt. Oliver    66.110410
# 68       California-Kirkbride   138.810568
# 69      Spring Hill-City View   407.178442
# 70                   Sheraden   568.085124
# 71            Stanton Heights   472.440891
# 72                  Beechview   933.888867
# 73                  St. Clair   199.075799
# 74                    Chateau   244.807878
# 75                  Shadyside   588.903018
# 76                Summer Hill   282.812388
# 77               West Oakland   149.459178
# 78                    Windgap   266.837987
# 79              Spring Garden   170.945932
# 80        Squirrel Hill South  1713.027416
# 81             Strip District   389.240679
# 82             Swisshelm Park   303.097360
# 83                Perry South   580.061539
# 84        Upper Lawrenceville   258.491299
# 85              Regent Square   125.580030
# 86            Terrace Village   207.771956
# 87                    Elliott   387.769846
# 88           South Side Flats   591.562688
# 89                   Fineview   159.033174

# %% [markdown]
# ### Plotting Data

# %%
# read the CSV file
df = pd.read_csv('Neighborhoods.csv')

# Select specific columns using iloc
filtered_df = df.iloc[:, [21, 23]]

# Rename columns 
filtered_df.columns = ['hood', 'acres']

# converting acres to a numeric
filtered_df.loc[:,'acres'] = filtered_df['acres'].astype(float)

# Sort by 'acres' in ascending order and select top 10
top_10 = filtered_df.sort_values(by='acres', ascending=True).head(10)

# Plot the bar graph
plt.figure(figsize=(10, 6))
plt.barh(top_10['hood'], top_10['acres'], color='blue')  # Horizontal bar for readability
plt.xlabel('Acres')
plt.ylabel('Neighborhood')
plt.title('Top 10 Neighborhoods by Acres (Ascending Order)')
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ## Putting it all together

# %%
land_area = filtered_df.set_index('hood')['acres']

# Normalizing fires and land area (crime is already done)
normalized_fires = neighborhood_counts.div(neighborhood_counts.mean())
normalized_land = land_area.sort_values(ascending=True).div(land_area.mean())

# Normalization doesn't bring everything down to a range of 0-1, it brings it down to a value representing a percentage difference from the mean.
# Therefore, a neighborhood with much better land area is ranked as such, and we don't lose the extremes in normalization.

# Getting a final score
final_score = (normalized_land.sub(normalized_fires).sub(normalized_crime_data)).sort_values(ascending=True)

# Outputting the value
final_score
# Out:
# South Side Flats            -5.342362
# East Liberty                -4.835271
# Central Business District   -4.725335
# Knoxville                   -4.193725
# Homewood South              -4.025060
# Carrick                     -3.939372
# Homewood North              -3.378715
# Bloomfield                  -3.298079
# Mount Washington            -3.262357
# East Allegheny              -3.156595
# Sheraden                    -2.599409
# Perry South                 -2.532478
# Allentown                   -2.482697
# Shadyside                   -2.411631
# Terrace Village             -2.358929
# Central Northside           -2.098254
# Garfield                    -2.051544
# Larimer                     -2.050816
# Central Oakland             -2.030875
# Crawford-Roberts            -1.999179
# Middle Hill                 -1.881666
# Bluff                       -1.863888
# Brighton Heights            -1.780188
# East Hills                  -1.753228
# Beltzhoover                 -1.581911
# North Oakland               -1.542435
# Hazelwood                   -1.511368
# South Side Slopes           -1.490378
# Marshall-Shadeland          -1.477700
# Troy Hill                   -1.402547
# Spring Hill-City View       -1.320471
# Manchester                  -1.155036
# Fineview                    -1.130370
# Greenfield                  -1.037016
# South Oakland               -1.034521
# West Oakland                -0.941792
# Allegheny Center            -0.886039
# Northview Heights           -0.881775
# Homewood West               -0.851498
# Lower Lawrenceville         -0.850373
# Strip District              -0.796114
# Upper Lawrenceville         -0.787720
# Elliott                     -0.704609
# Bedford Dwellings           -0.666636
# Friendship                  -0.651282
# California-Kirkbride        -0.650355
# Central Lawrenceville       -0.603713
# North Shore                 -0.601138
# Beechview                   -0.599711
# Upper Hill                  -0.588243
# Allegheny West              -0.575600
# Point Breeze North          -0.478404
# Crafton Heights             -0.408520
# Polish Hill                 -0.321006
# Lincoln-Lemington-Belmar    -0.318967
# Arlington                   -0.295537
# Brookline                   -0.272740
# West End                    -0.261330
# Morningside                 -0.253895
# Esplen                      -0.216169
# Perry North                 -0.214935
# Arlington Heights           -0.198918
# Mt. Oliver                  -0.176238
# Spring Garden               -0.167679
# Squirrel Hill North         -0.130833
# Chartiers City              -0.094363
# South Shore                 -0.070404
# Squirrel Hill South         -0.010137
# Highland Park                0.010584
# Stanton Heights              0.026728
# Bon Air                      0.068810
# Overbrook                    0.068934
# Regent Square                0.075654
# Chateau                      0.084131
# Windgap                      0.124983
# Oakwood                      0.182025
# Duquesne Heights             0.223550
# St. Clair                    0.259799
# Point Breeze                 0.321264
# Glen Hazel                   0.378203
# Ridgemont                    0.398975
# Summer Hill                  0.434867
# Westwood                     0.449385
# East Carnegie                0.518328
# Swisshelm Park               0.528062
# Banksville                   0.663906
# Lincoln Place                0.665242
# New Homestead                1.018272
# Fairywood                    1.293202
# Hays                         2.467176
# dtype: float64

# %% [markdown]
# ### Plotting The Data

# %%
plt.figure(figsize=(10,5))

plt.bar(final_score.index[-1:-11:-1], final_score.values[-1:-11:-1], color='darkgreen')
plt.title("Top 10 Best Neighborhoods in Pittsburgh", fontweight='bold', fontsize=24)
#plt.xlabel("Neighborhood", fontweight='bold')
plt.ylabel("Weighted Crimes", fontweight='bold')
plt.figsize = (10,100)

plt.xticks(rotation=60, rotation_mode='default')

plt.show()

# %% [markdown]
# ### Best Neighborhood: ***Hays*** with a score of 2.47!

# %% [markdown]
# # Conclusion
# ---

# %% [markdown]
# Though at first I would have assumed one of the more central neighborhoods may have been better (I was rooting for Oakland, of course), I should have realized that one of the more rural neighborhoods would turn out to be best in the end. Besides it just being larger (which was obviously one of our metrics), the rural nature of the neighborhood also contributes to lower crime, and likely fewer fires (as there are fewer people, or fewer buildings close together, etc). Having seen all of the data, and done some research about Hays, I have come to like it. Beyond simple land area, it actually has the most green space of any Pittsburgh neighborhood, and is scheduled to contain the city's largest park in the coming years. Overall, the data has changed my mind about which neighborhood is the best.
# <p style="text-align: right;">- Jayden</p>
